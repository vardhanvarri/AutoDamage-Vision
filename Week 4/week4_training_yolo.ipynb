# %%
# ==========================================
# Week 4 – Training an Object Detector
# ==========================================

"""
Objective:
Train a YOLO-based object detection model
on the prepared vehicle damage dataset.
"""

# TODO: Install YOLO library
# !pip install ultralytics

# %%
# ------------------------------------------
# Step 1: Imports
# ------------------------------------------

# TODO:
# from ultralytics import YOLO
# import os

# %%
# ------------------------------------------
# Step 2: Dataset Configuration
# ------------------------------------------

# TODO:
# - Define path to dataset YAML file
# - Verify paths to train and validation data

# %%
# ------------------------------------------
# Step 3: Model Initialization
# ------------------------------------------

# TODO:
# - Load a pretrained YOLO model
# - Print model summary

# %%
# ------------------------------------------
# Step 4: Training Configuration
# ------------------------------------------

# TODO:
# - Define training parameters
#   epochs (small)
#   batch size
#   image size
#   learning rate

# %%
# ------------------------------------------
# Step 5: Train the Model
# ------------------------------------------

# TODO:
# - Start training
# - Monitor loss values

# %%
# ------------------------------------------
# Step 6: Save Outputs
# ------------------------------------------

# TODO:
# - Save trained weights
# - Save training logs

# %%
# ------------------------------------------
# Reflection
# ------------------------------------------
# - What changes during training?
# - Why might training be unstable?
