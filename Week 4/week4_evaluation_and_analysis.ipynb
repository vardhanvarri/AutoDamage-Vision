# %%
# ==========================================
# Week 4 – Evaluation & Error Analysis
# ==========================================

"""
Objective:
Evaluate trained object detector and
understand its strengths and weaknesses.
"""

# TODO: Import required libraries
# from ultralytics import YOLO
# import matplotlib.pyplot as plt
# import cv2
# import os

# %%
# ------------------------------------------
# Step 1: Load Trained Model
# ------------------------------------------

# TODO:
# - Load trained YOLO weights

# %%
# ------------------------------------------
# Step 2: Run Inference on Validation Images
# ------------------------------------------

# TODO:
# - Select validation images
# - Run inference

# %%
# ------------------------------------------
# Step 3: Visualize Predictions
# ------------------------------------------

# TODO:
# - Draw predicted bounding boxes
# - Display confidence scores

# %%
# ------------------------------------------
# Step 4: Understanding Metrics
# ------------------------------------------

# TODO:
# - Print evaluation metrics
# - Interpret IoU, precision, recall

# %%
# ------------------------------------------
# Step 5: Error Analysis
# ------------------------------------------

# TODO:
# - Identify false positives
# - Identify missed detections
# - Categorize common failure cases

# %%
# ------------------------------------------
# Final Reflection
# ------------------------------------------
# - What worked well?
# - What failed?
# - What would you improve with more data or time?
