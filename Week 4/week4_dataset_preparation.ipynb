# %%
# ==========================================
# Week 4 – Dataset Preparation for Training
# ==========================================

"""
Objective:
Prepare a small, clean subset of the vehicle damage dataset
for object detection training.
"""

# TODO: Import required libraries
# import os
# import random
# import shutil
# import matplotlib.pyplot as plt

# %%
# ------------------------------------------
# Step 1: Dataset Overview
# ------------------------------------------

# TODO:
# - Define dataset root directory
# - Inspect available images and annotations
# - Print dataset statistics (counts)

# %%
# ------------------------------------------
# Step 2: Subset Selection
# ------------------------------------------

# TODO:
# - Select a small random subset of images
# - Ensure diversity in damage types
# - Store selected file names

# %%
# ------------------------------------------
# Step 3: Train / Validation Split
# ------------------------------------------

# TODO:
# - Split selected data into train and validation sets
# - Typical split: 80% train, 20% validation

# %%
# ------------------------------------------
# Step 4: Folder Structure Creation
# ------------------------------------------

# Expected structure:
# dataset/
# ├── images/
# │   ├── train/
# │   └── val/
# └── labels/
#     ├── train/
#     └── val/

# TODO:
# - Create directories
# - Copy images and labels into correct folders

# %%
# ------------------------------------------
# Reflection
# ------------------------------------------
# - Why is data cleanliness important for training?
# - What could go wrong with bad annotations?
